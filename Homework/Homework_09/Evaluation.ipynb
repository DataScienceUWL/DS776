# %% [markdown]
# ### **Evaluation Criteria**
#
# **Original, Thoughtful, In-Depth Analysis (12 pts)**:
#
# **Completeness, Figures (12 pts)**:
#
# **Personalization, Applications (12 pts)**:
#
# **Citations, Supporting Evidence (8 pts)**:
#
# **Presentation and Length (6 pts)**:
