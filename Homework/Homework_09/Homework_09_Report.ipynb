# %% [markdown]
# # Homework 9: Transformer Architecture Report
#
# **Name:** [Your Name Here]
# **Total Points:** 40
#
# ## Submission Checklist
# - [ ] Report is 1500-2000 words
# - [ ] All 6 sections completed with clear headers
# - [ ] At least 3 hand-drawn diagrams included
# - [ ] At least 3 citations (one not from OpenAI/HuggingFace)
# - [ ] Personalized examples from your field of interest
# - [ ] Report exported to HTML or saved as PDF
# - [ ] Canvas filename includes `_GRADE_THIS_ONE`
# - [ ] Files uploaded to Canvas
#
# ---
#
# ## **1. Introduction**

# %% [markdown]
# ## **2. Model Architectures & Attention Mechanisms**

# %% [markdown]
# ## **3. Pretraining Objectives & Key Terminology**

# %% [markdown]
# ## **4. Fine-Tuning Approaches**

# %% [markdown]
# ## **5. Real-World Applications & Your Professional Interests**

# %% [markdown]
# ## **6. Conclusion**

# %% [markdown]
# ### Export Notebook to HTML for Canvas Upload
#
# Uncomment the two lines below and run the cell to export the current notebook to HTML.

# %%
# from introdl import export_this_to_html
# export_this_to_html()
